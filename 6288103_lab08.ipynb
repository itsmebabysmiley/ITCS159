# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Exercise1

# %%
plt. plot (1 , 3 , 'bo')
plt. plot (2 , 2 , 'ro')
# Out:
# [&lt;matplotlib.lines.Line2D at 0x1bca005c520&gt;]
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# <mark>Answer</mark>
#
# (xlable,ylable)

# %%
plt. plot ([1 , 3 , 12 , 30])
plt. plot ([1 , 4 , 3 , 12])
# Out:
# [&lt;matplotlib.lines.Line2D at 0x1bca216f3a0&gt;]
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
plt. plot ([0 , 3 , 5 , 6] , [0 , 5 , 15 , 10])
plt. plot ([0 , 1 , 2 , 6] , [10 , 8 , 1 , 3])
# Out:
# [&lt;matplotlib.lines.Line2D at 0x1bca21d4100&gt;]
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ## Exercise2

# %%
plt. plot ([0 , 3 , 5 , 6] , [0 , 5 , 15 , 10] , '--',label ='A',color ="pink", linewidth =5)
plt. plot ([0 , 1 , 2 , 6] , [10 , 8 , 1 , 3] , ':', label ='B',color ="lightblue", linewidth =2)
plt. legend ()
# Out:
# &lt;matplotlib.legend.Legend at 0x1bca3ad7760&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
fig = plt . figure ( figsize =(6 ,2) )
plt. plot ([0 , 3 , 5 , 6] , [0 , 5 , 15 , 10])
plt. plot ([0 , 1 , 2 , 6] , [10 , 8 , 1 , 3])
# Out:
# [&lt;matplotlib.lines.Line2D at 0x1bca3ad9880&gt;]
# &lt;Figure size 432x144 with 1 Axes&gt;

# %% [markdown]
# ## Exercise3

# %%
plt. barh ([1 ,2 ,3] ,[0 ,1 ,5])
# Out:
# &lt;BarContainer object of 3 artists&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
n = 6
x = np.arange(n)
y1 = (1 -x/ float (n) )
y2 = (1 -x/ float (n) )
plt.bar (x, +y1 , facecolor ='blue', edgecolor ='white')
plt.bar (x, -y2 , facecolor ='red', edgecolor ='white')
# Out:
# &lt;BarContainer object of 6 artists&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
plt. barh ([1 ,2 ,3] ,[0 ,1 ,5],facecolor ='black')
plt. barh ([2 ,2 ,5] ,[1 ,1 ,1],facecolor ='blue')
plt.bar ([1 ,2 ,3] ,[3 ,4 ,5],facecolor ='green')
# Out:
# &lt;BarContainer object of 3 artists&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;

# %% [markdown]
# ## Exercise4

# %%
fig = plt.figure ()
ax = fig.add_subplot(111)
ax.barh([1 ,2 ,3] ,[0 ,1 ,5])
# Out:
# &lt;BarContainer object of 3 artists&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
fig = plt.figure ( figsize =(20 ,10) )
ax1 = fig.add_subplot (131)
ax2 = fig.add_subplot (132)
ax3 = fig.add_subplot (133)
ax1.barh ([1 ,2 ,3] ,[0 ,1 ,5])
ax2.barh ([2 ,2 ,5] ,[1 ,1 ,1])
ax3.bar ([1 ,2 ,3] ,[3 ,4 ,5])
# Out:
# &lt;BarContainer object of 3 artists&gt;
# &lt;Figure size 1440x720 with 3 Axes&gt;

# %%
fig = plt . figure ()
ax = fig. add_subplot (111)
N = 30
x = np. random . rand (N)
y = np. random . rand (N)
scat = ax. scatter (x, y, 200 ,edgecolors = 'k', facecolors ='c')
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
rng = np. arange (50)
rnd = np. random . randint (0 , 10 , size =(3 , rng . size ) )
yrs = 1950 + rng
fig , ax = plt. subplots ( figsize =(5 , 3) )
ax. stackplot (yrs , rng + rnd , labels =[ 'Eastasia', 'Eurasia','Oceania'])
ax. set_title ('Combined debt growth over time')
ax. legend ( loc='upper left')
ax. set_ylabel ('Total debt')
ax. set_xlim ( xmin = yrs [0] , xmax = yrs [ -1])
fig. tight_layout ()
# Out:
# &lt;Figure size 360x216 with 1 Axes&gt;

# %%
import seaborn as sns

# %% [markdown]
# ## Excerise9

# %%
sns.set ()
tips = sns.load_dataset ("tips")
sns. relplot (x="total_bill", y="tip", hue ="smoker", style ="smoker", size ="size", data = tips )
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# &lt;Figure size 417.475x360 with 1 Axes&gt;

# %% [markdown]
# <mark>Answer</mark>
#
# 5 colums

# %%
sns. relplot (x="total_bill", y="tip",col ="time",hue ="smoker", style ="smoker", size ="size", data = tips )
# Out:
# &lt;seaborn.axisgrid.FacetGrid at 0x1bca4eaa850&gt;
# &lt;Figure size 777.475x360 with 2 Axes&gt;

# %%
sns. relplot (x="total_bill", y="tip", col ="time", hue ="size",style ="smoker", size ="size", palette ="YlGnBu", markers =["D","o"] , sizes =(10 , 125) , edgecolor =".2", linewidth =.5 ,
alpha =.75 , data = tips )
# Out:
# &lt;seaborn.axisgrid.FacetGrid at 0x1bca6211610&gt;
# &lt;Figure size 777.475x360 with 2 Axes&gt;

# %%
sns.set ()
tips = sns. load_dataset ("tips")
sns. relplot (x="total_bill", y="tip", col ="smoker", hue ="sex", kind ="line", data = tips )
# Out:
# &lt;seaborn.axisgrid.FacetGrid at 0x1bcb3450ac0&gt;
# &lt;Figure size 796.35x360 with 2 Axes&gt;

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Exercise10

# %%
sns.set ()
tips = sns. load_dataset ("tips")
sns. catplot (x="day", y="total_bill", hue ="smoker", kind ="swarm", data = tips )
plt. show ()
# Out:
# &lt;Figure size 417.475x360 with 1 Axes&gt;

# %% [markdown]
# <mark>Answer</mark>
# <code>
# sns.relplot(x="day", y="total_bill", hue ="smoker", kind ="line", data = tips )
# </code>

# %%
sns. catplot (x="day", y="total_bill", hue ="smoker", kind ="violin", split =True , data = tips )
# Out:
# &lt;seaborn.axisgrid.FacetGrid at 0x1bcb30d0190&gt;
# &lt;Figure size 417.475x360 with 1 Axes&gt;

# %%
sns. catplot (x="day", y="total_bill", hue ="smoker", kind ="bar", data = tips )
# Out:
# &lt;seaborn.axisgrid.FacetGrid at 0x1bcb5972ee0&gt;
# &lt;Figure size 417.475x360 with 1 Axes&gt;
