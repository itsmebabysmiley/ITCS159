# %% [markdown]
# Iris.data
# http://archive.ics.uci.edu/ml/machine-learning-databases/iris/

# %%
import sys
import scipy
import numpy
import matplotlib
import pandas
import sklearn

# %%
print ('Python : {} '.format (sys.version ) )
print ('scipy : {} '.format ( scipy.__version__ ) )
print ('numpy : {} '.format ( numpy.__version__ ) )
print ('matplotlib : {} '.format ( matplotlib.__version__ ) )
print ('pandas : {} '.format ( pandas.__version__ ) )
print ('sklearn : {} '.format ( sklearn.__version__ ) )
# Out:
# Python : 3.8.6 (tags/v3.8.6:db45529, Sep 23 2020, 15:52:53) [MSC v.1927 64 bit (AMD64)]
# scipy : 1.5.2
# numpy : 1.19.1
# matplotlib : 3.3.1
# pandas : 1.1.2
# sklearn : 0.23.2

# %%
import pandas
from pandas .plotting import scatter_matrix
import matplotlib .pyplot as plt
from sklearn import model_selection
from sklearn .neighbors import KNeighborsClassifier

# %%
names=['sepal-length','sepal-width','petal-length','petal-width','class']
ds=pandas.read_csv('iris.data',names=names)

# %%
ds
# Out:
#      sepal-length  sepal-width  petal-length  petal-width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
print (ds.shape)
print (ds.head(20))
print (ds.describe())
print (ds.groupby('class').size())
# Out:
# (150, 5)
#     sepal-length  sepal-width  petal-length  petal-width        class
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %%
# 50 number of setosa, versicolor, virginica

# %%
ds.plot(kind='box',subplots=True,layout=(2,2),sharex=False,sharey=False)
plt.show()

# %%
array = ds.values
X = array [: ,0:4]
Y = array [: ,4]

# %%
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3.0, 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5.0, 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5.0, 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3.0, 1.4, 0.1],
#        [4.3, 3.0, 1.1, 0.1],
#        [5.8, 4.0, 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1.0, 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5.0, 3.0, 1.6, 0.2],
#        [5.0, 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
Y
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
# ...

# %%
# x is sepal-length  sepal-width  petal-length  petal-width
# y is type of iris

# %%
test_size=0.20
seed=7
X_train,X_test,Y_train,Y_test=model_selection.\
train_test_split(X,Y,\
test_size=test_size,random_state=seed)

# %%
# train_test_split will split arrays or matrices into random train and test subsets.

# %%
print(X_train,X_test,Y_train,Y_test)
# Out:
# [[6.2 2.8 4.8 1.8]
#  [5.7 2.6 3.5 1.0]
#  [4.6 3.6 1.0 0.2]
#  [6.9 3.1 5.4 2.1]
#  [6.4 2.9 4.3 1.3]
#  [4.8 3.0 1.4 0.3]
#  [5.5 3.5 1.3 0.2]
#  [5.4 3.9 1.7 0.4]
#  [5.1 3.5 1.4 0.3]
#  [7.1 3.0 5.9 2.1]
#  [6.7 3.3 5.7 2.1]
#  [6.8 2.8 4.8 1.4]
#  [6.4 2.8 5.6 2.2]
#  [6.5 3.0 5.5 1.8]
#  [5.7 3.0 4.2 1.2]
#  [5.0 3.3 1.4 0.2]
#  [6.7 3.1 4.4 1.4]
#  [6.0 2.2 4.0 1.0]
#  [6.4 2.7 5.3 1.9]
#  [4.7 3.2 1.6 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.1 3.4 1.5 0.2]
#  [7.7 3.8 6.7 2.2]
#  [4.3 3.0 1.1 0.1]
#  [6.3 3.3 6.0 2.5]
#  [5.5 2.4 3.7 1.0]
#  [5.0 2.0 3.5 1.0]
#  [6.5 2.8 4.6 1.5]
#  [5.0 3.4 1.6 0.4]
#  [4.4 2.9 1.4 0.2]
#  [5.0 3.5 1.6 0.6]
#  [6.7 3.1 4.7 1.5]
#  [7.3 2.9 6.3 1.8]
#  [5.5 2.6 4.4 1.2]
#  [5.2 2.7 3.9 1.4]
#  [5.7 4.4 1.5 0.4]
#  [7.2 3.2 6.0 1.8]
#  [5.4 3.4 1.7 0.2]
#  [5.8 4.0 1.2 0.2]
#  [6.1 2.6 5.6 1.4]
#  [5.7 2.5 5.0 2.0]
#  [4.8 3.0 1.4 0.1]
#  [6.5 3.0 5.8 2.2]
#  [4.6 3.2 1.4 0.2]
#  [6.6 2.9 4.6 1.3]
#  [6.7 3.0 5.2 2.3]
#  [6.1 3.0 4.6 1.4]
# ...

# %%
test_size=0.10
seed=5
X_train,X_test,Y_train,Y_test=model_selection.\
train_test_split(X,Y,\
test_size=test_size,random_state=seed)

# %%
print(X_train,X_test,Y_train,Y_test)
# Out:
# [[5.1 3.3 1.7 0.5]
#  [6.3 2.7 4.9 1.8]
#  [7.4 2.8 6.1 1.9]
#  [5.1 3.7 1.5 0.4]
#  [4.8 3.0 1.4 0.1]
#  [6.1 2.8 4.0 1.3]
#  [6.4 2.8 5.6 2.1]
#  [5.3 3.7 1.5 0.2]
#  [6.3 2.5 4.9 1.5]
#  [5.6 3.0 4.1 1.3]
#  [6.2 3.4 5.4 2.3]
#  [6.4 2.9 4.3 1.3]
#  [5.7 2.9 4.2 1.3]
#  [6.1 2.9 4.7 1.4]
#  [6.4 2.8 5.6 2.2]
#  [5.1 3.4 1.5 0.2]
#  [5.5 2.3 4.0 1.3]
#  [5.7 2.6 3.5 1.0]
#  [5.4 3.7 1.5 0.2]
#  [7.0 3.2 4.7 1.4]
#  [5.0 3.3 1.4 0.2]
#  [5.0 3.5 1.6 0.6]
#  [7.7 3.0 6.1 2.3]
#  [5.0 3.5 1.3 0.3]
#  [6.4 3.2 5.3 2.3]
#  [5.8 2.7 5.1 1.9]
#  [5.6 2.5 3.9 1.1]
#  [5.1 3.5 1.4 0.3]
#  [5.1 3.8 1.6 0.2]
#  [6.5 2.8 4.6 1.5]
#  [6.2 2.8 4.8 1.8]
#  [5.9 3.0 4.2 1.5]
#  [6.7 3.3 5.7 2.1]
#  [7.7 3.8 6.7 2.2]
#  [5.4 3.4 1.7 0.2]
#  [6.3 2.5 5.0 1.9]
#  [5.0 3.2 1.2 0.2]
#  [4.6 3.4 1.4 0.3]
#  [5.7 4.4 1.5 0.4]
#  [5.2 3.4 1.4 0.2]
#  [6.2 2.9 4.3 1.3]
#  [6.3 3.3 4.7 1.6]
#  [5.5 2.4 3.7 1.0]
#  [5.1 2.5 3.0 1.1]
#  [5.9 3.0 5.1 1.8]
#  [5.0 2.0 3.5 1.0]
#  [6.5 3.0 5.2 2.0]
# ...

# %%
#Exercise 9
# I will choose 1 because If I remember correctly it has theory call 'the nearest neighbor'
# I think it can be either odd or even.

# %%
irisML = KNeighborsClassifier(n_neighbors=17)
irisML.fit(X_train ,Y_train )
# Out:
# KNeighborsClassifier(n_neighbors=17)

# %%
prediction = irisML.predict(X_test)

# %%
prediction
# Out:
# array(['Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-setosa', 'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa'], dtype=object)

# %%
irisML.score( X_test , Y_test )
# Out:
# 0.9333333333333333

# %%
#Accuracy score

# %%
new_obj1 = [[5.2 ,4.3 ,5.6 ,1.6]]
output1 = irisML.predict(new_obj1)

# %%
output1
# Out:
# array(['Iris-virginica'], dtype=object)

# %%
new_obj2 = [[4.8, 3.4, 1.9, 0.2]]
output2 = irisML.predict(new_obj2)

# %%
output2
# Out:
# array(['Iris-setosa'], dtype=object)
